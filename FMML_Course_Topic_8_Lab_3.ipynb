# %% [markdown]
# <a href="https://colab.research.google.com/github/anukarri891/FMML_PROJECT_AND_LAB/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-26 16:58:54--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.108.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   213MB/s    in 0.3s
#
# 2024-03-26 16:58:55 (213 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 11680  1609.06826v1  Bibliographic analysis considers author's rese...    cs
# 22274  1511.04157v1  For regular particle filter algorithm or Seque...  stat
# 38746   1104.5284v1  In this work we are concerned with the detecti...    cs
# 14478  cs/0103007v1  A two-parameter model of word length measured ...    cs
# 29896  1711.00088v1  We describe a novel architecture for semantic ...    cs
# ...             ...                                                ...   ...
# 25202  1506.04912v1  In this paper, the problem of terahertz pulsed...    cs
# 11857  1702.08701v3  This paper aims at refined error analysis for ...    cs
# 7762   1803.01905v1  The implicit bias of gradient descent is not f...  stat
# 22343  1602.06701v2  We introduce a new approach for amortizing inf...  stat
# 39601  1610.01502v2  We use tools from geometric statistics to anal...    cs
#
#                                                    title  year  \
# 11680  Bibliographic Analysis with the Citation Netwo...  2016
# 22274  $k$-means: Fighting against Degeneracy in Sequ...  2015
# 38746  Content-Based Spam Filtering on Video Sharing ...  2011
# 14478  Two-parameter Model of Word Length "Language -...  2001
# 29896  Semantic Image Retrieval via Active Grounding ...  2017
# ...                                                  ...   ...
# 25202  Subsampled terahertz data reconstruction based...  2015
# 11857  Learning rates for classification with Gaussia...  2017
# 7762   Convergence of Gradient Descent on Separable Data  2018
# 22343  Inference Networks for Sequential Monte Carlo ...  2016
# 39601  Template shape estimation: correcting an asymp...  2016
#
#                                                 keywords
# 11680  [bibliographic, considers, bibliographic, docu...
# 22274  [algorithm, sequential, traditionally, depende...
# 38746  [concerned, detection, specifically, investiga...
# 14478  [parameter, syllables, comprising, parameter, ...
# 29896  [architecture, retrieval, particular, retrieva...
# ...                                                  ...
# 25202  [terahertz, reconstruction, addressed, incompl...
# 11857  [classification, functions, truncated, quadrat...
# 7762   [understood, classification, separable, soluti...
# 22343  [introduce, amortizing, inference, graphical, ...
# 39601  [geometric, statistics, estimation, procedure,...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 11680    [bibliographic, considers, bibliographic, docu...
# 22274    [algorithm, sequential, traditionally, depende...
# 38746    [concerned, detection, specifically, investiga...
# 14478    [parameter, syllables, comprising, parameter, ...
# 29896    [architecture, retrieval, particular, retrieva...
#                                ...
# 27727    [exhaustive, investigation, architectures, alg...
# 21821    [probabilistic, continuous, complexity, conjec...
# 37770    [customers, deterministic, parameters, practic...
# 16688    [conversational, interaction, utterance, activ...
# 21708    [probability, distributions, structure, partic...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8778 words.
# Out of those 4586 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="8575f971-32e3-425e-b3b2-de535aeadfe0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8575f971-32e3-425e-b3b2-de535aeadfe0")) {                    Plotly.newPlot(                        "8575f971-32e3-425e-b3b2-de535aeadfe0",                        [{"x":["parametric","publications","clustering","extension","performance","inference","algorithm","documents","demonstrates","combination","considers","efficient","baselines","providing","proportions","eventually","posterior","experimentally","advantage","particles","distribution","dependent","collapsed","traditionally","expectation","initializes","degeneracy","sequential","demonstrate","technically","specifically","application","stochastic","algorithms","practical","investigate","challenging","experiments","detection","processing","consideration","detecting","information","paramount","concerned","considering","preventing","feasibility","approaches","systematically","popularity","constrained","increasingly","filtering","optimization","completion","processes","syllables","parameter","comprising","collection","structure","capturing","component","description","particular","indicating","described","procedure","configuration","retrieval","preliminary","situation","resulting","instances","instantiations","grounding","comparing","similarity","situations","architecture","relationships","indispensable","distinguishing","complementary","addressing","achieving","beneficial","representations","locations","convolutional","descriptions","discriminative","limitations","attribute","generally","recognizing","experimental","characteristics","belonging","classification","categories","promising","annotations","combining","tradeoffs","suggesting","exploration","different","centralized","maximizes","decentralized","relevance","generates","coordination","objective","additional","communication","fundamentally","exploitation","constraints","programming","informally","propositional","semantics","implementation","transitive","straightforward","monotonic","confidence","especially","indicators","translators","translation","improvement","applications","linguistic","inferring","traditional","evaluation","expensive","contrasting","judgments","introduces","probabilistic","selective","inconsistency","invaluable","credibility","estimation","intelligent","correlation","subsequently","engineered","ingenious","distributions","corrected","modifying","importance","introduce","carefully","rejection","correction","motivated","reference","recognition","rotational","resolution","calculating","rigorously","respectively","statistics","definition","projecting","projected","projection","descriptor","available","neighboring","occlusion","technique","descriptors","techniques","exhibited","hierarchical","classifiers","extensive","selection","automated","asymptotic","discrimination","important","effectiveness","hypothesis","properties","classifier","divergence","categorization","framework","foundation"],"y":[43,11,152,72,888,226,830,66,59,122,40,380,68,95,3,14,45,51,104,4,234,79,1,22,34,1,2,75,556,2,138,235,115,614,128,134,261,572,361,289,29,72,705,7,20,62,15,18,427,26,30,61,59,47,313,28,93,2,124,12,57,322,37,93,75,271,11,61,103,29,98,41,39,131,105,4,12,69,162,46,245,58,7,9,39,25,77,21,238,43,365,30,97,59,29,80,33,385,93,19,475,58,114,61,113,5,15,54,723,5,9,7,31,57,9,178,110,66,11,25,157,104,4,26,107,132,6,29,15,49,143,8,3,105,141,436,69,26,157,251,64,7,15,85,157,17,7,2,3,198,66,66,24,7,0,107,11,12,83,310,25,8,16,67,74,380,5,110,14,8,110,70,51,8,15,51,27,280,12,27,261,54,365,5,105,121,182,160,97,21,19,365,204,58,212,146,23,22,538,18],"type":"bar"},{"x":["parametric","publications","clustering","extension","performance","infer ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4586,), (4586, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8025

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>The</span> <span style=''>Rank</span> <span style='background-color:rgba(0, 255, 0, 0.3580246913580246);'>Frequency</span> <span style=''>Analysis</span> <span style=''>for</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.39622641509433965);'>Functional</span> <span style=''>Style</span> <span style=''>Corpora</span> <span style=''>in</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>Ukrainian</span> <span style=''>Language</span> <br/><br/><span style=''>We</span> <span style=''>use</span> <span style=''>the</span> <span style=''>rank</span> <span style='background-color:rgba(0, 255, 0, 0.3580246913580246);'>frequency</span> <span style=''>analysis</span> <span style=''>for</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>estimation</span> <span style=''>of</span> <span style=''>Kernel</span> <span style='background-color:rgba(0, 255, 0, 0.7368421052631579);'>Vocabulary</span> <span style=''>size</span> <span style=''>within</span> <span style=''>specific</span> <span style=''>corpora</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>Ukrainian</span> <span style=''>The</span> <span style='background-color:rgba(255, 0, 0, 0.5999999999999999);'>extrapolation</span> <span style=''>of</span> <span style=''>high</span> <span style=''>rank</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>behaviour</span> <span style=''>is</span> <span style=''>utilized</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>estimation</span> <span style=''>of</span> <span style=''>the</span> <span style=''>total</span> <span style='background-color:rgba(0, 255, 0, 0.7368421052631579);'>vocabulary</span> <span style=''>size</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Fast</span> <span style=''>MCMC</span> <span style=''>sampling</span> <span style=''>for</span> <span style=''>Markov</span> <span style=''>jump</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>processes</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>continuous</span> <span style=''>time</span> <span style=''>Bayesian</span> <span style=''>networks</span> <br/><br/><span style=''>Markov</span> <span style=''>jump</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>processes</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>continuous</span> <span style=''>time</span> <span style=''>Bayesian</span> <span style=''>networks</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>important</span> <span style=''>classes</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>continuous</span> <span style=''>time</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dynamical</span> <span style=''>systems</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>tackle</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inferring</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>unobserved</span> <span style=''>paths</span> <span style=''>in</span> <span style=''>these</span> <span style=''>models</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introducing</span> <span style=''>a</span> <span style=''>fast</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>auxiliary</span> <span style=''>variable</span> <span style=''>Gibbs</span> <span style=''>sampler</span> <span style=''>Our</span> <span style=''>approach</span> <span style=''>is</span> <span style=''>based</span> <span style=''>on</span> <span style=''>the</span> <span style=''>idea</span> <span style=''>of</span> <span style=''>uniformization</span> <span style=''>and</span> <span style=''>sets</span> <span style=''>up</span> <span style=''>a</span> <span style=''>Markov</span> <span style=''>chain</span> <span style=''>over</span> <span style=''>paths</span> <span style=''>by</span> <span style=''>sampling</span> <span style=''>a</span> <span style=''>finite</span> <span style=''>set</span> <span style=''>of</span> <span style=''>virtual</span> <span style=''>jump</span> <span style=''>times</span> <span style=''>and</span> <span style=''>then</span> <span style=''>running</span> <span style=''>a</span> <span style=''>standard</span> <span style=''>hidden</span> <span style=''>Markov</span> <span style=''>model</span> <span style=''>forward</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>filtering</span> <span style=''>backward</span> <span style=''>sampling</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>over</span> <span style=''>states</span> <span style=''>at</span> <span style=''>the</span> <span style=''>set</span> <span style=''>of</span> <span style=''>extant</span> <span style=''>and</span> <span style=''>virtual</span> <span style=''>jump</span> <span style=''>times</span> <span style=''>We</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>demonstrate</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>significant</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computational</span> <span style=''>benefits</span> <span style=''>over</span> <span style=''>a</span> <span style=''>state</span> <span style=''>of</span> <span style=''>the</span> <span style=''>art</span> <span style=''>Gibbs</span> <span style=''>sampler</span> <span style=''>on</span> <span style=''>a</span> <span style=''>number</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>continuous</span> <span st ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Sum</span> <span style=''>Product</span> <span style=''>Networks</span> <span style=''>for</span> <span style=''>Hybrid</span> <span style=''>Domains</span> <br/><br/><span style=''>While</span> <span style=''>all</span> <span style=''>kinds</span> <span style=''>of</span> <span style=''>mixed</span> <span style=''>data</span> <span style=''>from</span> <span style=''>personal</span> <span style=''>data</span> <span style=''>over</span> <span style=''>panel</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>scientific</span> <span style=''>data</span> <span style=''>to</span> <span style=''>public</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.4814814814814815);'>commercial</span> <span style=''>data</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3082706766917292);'>collected</span> <span style=''>and</span> <span style=''>stored</span> <span style=''>building</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probabilistic</span> <span style='background-color:rgba(255, 0, 0, 0.3006134969325154);'>graphical</span> <span style=''>models</span> <span style=''>for</span> <span style=''>these</span> <span style=''>hybrid</span> <span style=''>domains</span> <span style=''>becomes</span> <span style=''>more</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>difficult</span> <span style=''>Users</span> <span style=''>spend</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>significant</span> <span style=''>amounts</span> <span style=''>of</span> <span style=''>time</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>identifying</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.406896551724138);'>parametric</span> <span style=''>form</span> <span style=''>of</span> <span style=''>the</span> <span style=''>random</span> <span style='background-color:rgba(255, 0, 0, 0.352657004830918);'>variables</span> <span style=''>(Gaussian</span> <span style=''>Poisson</span> <span style=''>Logit</span> <span style=''>etc)</span> <span style=''>involved</span> <span style=''>and</span> <span style=''>learning</span> <span style=''>the</span> <span style=''>mixed</span> <span style=''>models</span> <span style=''>To</span> <span style=''>make</span> <span style=''>this</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>difficult</span> <span style=''>task</span> <span style=''>easier</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>the</span> <span style=''>first</span> <span style='background-color:rgba(0, 255, 0, 0.5882352941176471);'>trainable</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probabilistic</span> <span style=''>deep</span> <span style='background-color:rgba(0, 255, 0, 0.53125);'>architecture</span> <span style=''>for</span> <span style=''>hybrid</span> <span style=''>domains</span> <span style=''>that</span> <span style=''>features</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>tractable</span> <span style=''>queries</span> <span style=''>It</span> <span style=''>is</span> <span style=''>based</span> <span style=''>on</span> <span style=''>Sum</span> <span style=''>Product</span> <span style=''>Networks</span> <span style=''>(SPNs)</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3103448275862068);'>piecewise</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>polynomial</span> <span style=''>leave</span> <span style='background-color:rgba(255, 0, 0, 0.33125000000000016);'>distributions</span> <span style=''>together</span> <span style=''>with</span> <span style=''>novel</span> <span style='background-color:rgba(255, 0, 0, 0.6692913385826771);'>nonparametric</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>decomposition</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.36363636363636 ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Sparsity</span> <span style=''>based</span> <span style=''>Defense</span> <span style=''>against</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Adversarial</span> <span style=''>Attacks</span> <span style=''>on</span> <span style=''>Linear</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Classifiers</span> <br/><br/><span style=''>Deep</span> <span style=''>neural</span> <span style=''>networks</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>represent</span> <span style=''>the</span> <span style=''>state</span> <span style=''>of</span> <span style=''>the</span> <span style=''>art</span> <span style=''>in</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>in</span> <span style=''>a</span> <span style=''>growing</span> <span style=''>number</span> <span style=''>of</span> <span style=''>fields</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>including</span> <span style=''>vision</span> <span style=''>speech</span> <span style=''>and</span> <span style=''>natural</span> <span style=''>language</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>processing</span> <span style=''>However</span> <span style=''>recent</span> <span style=''>work</span> <span style=''>raises</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>important</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>questions</span> <span style=''>about</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>robustness</span> <span style=''>of</span> <span style=''>such</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>architectures</span> <span style=''>by</span> <span style=''>showing</span> <span style=''>that</span> <span style=''>it</span> <span style=''>is</span> <span style=''>possible</span> <span style=''>to</span> <span style=''>induce</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style=''>errors</span> <span style=''>through</span> <span style=''>tiny</span> <span style=''>almost</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>imperceptible</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>perturbations</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Vulnerability</span> <span style=''>to</span> <span style=''>such</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>adversarial</span> <span style=''>attacks</span> <span style=''>or</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>adversarial</span> <span style=''>examples</span> <span style=''>has</span> <span style=''>been</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conjectured</span> <span style=''>to</span> <span style=''>be</span> <span style=''>due</span> <span style=''>to</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>excessive</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>linearity</span> <span style=''>of</span> <span style=''>deep</span> <span style=''>networks</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>study</span> <span style=''>this</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>phenomenon</span> <span style=''>in</span> <span style=''>the</span> <span style=''>setting</span> <span style=''>of</span> <span style=''>a</span> <span style=''>linear</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classifier</span> <span style=''>and</span> <span style=''>show</span> <span style=''>that</span> <span style=''>it</span> <span style=''>is</span> <span style=''>possible</span> <span style=''>to</span> <span style=''>exploit</span> <span style=''>sparsity</span> <span style=''>in</span> <span style=''>natural</span> <span style=''>data</span> <span style=''>to</span> <span style=''>combat</span> <span style=''>ell</span> <span style=''>infty</span> <span style=''>bounded</span> < ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	experimental (0.13809182209469154)
# 	architecture (0.08787661406025825)
# 	segmentation (0.06958393113342898)
# 	representation (0.13163558106169296)
# 	knowledge (0.1327116212338594)
# 	information (0.2528694404591105)
# 	detection (0.12948350071736012)
# 	different (0.25932568149210905)
# 	convolutional (0.13091822094691535)
# 	recognition (0.13629842180774748)
#
# Some Statistics words are:
# 	algorithm (0.38767395626242546)
# 	variables (0.13916500994035785)
# 	stochastic (0.1341948310139165)
# 	distribution (0.18041749502982107)
# 	theoretical (0.14910536779324055)
# 	estimation (0.17196819085487078)
# 	statistical (0.15308151093439365)
# 	inference (0.19731610337972166)
# 	dimensional (0.176441351888668)
# 	regression (0.1779324055666004)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="a6d34e3a-19c2-4060-b8e8-877c1e214dc9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a6d34e3a-19c2-4060-b8e8-877c1e214dc9")) {                    Plotly.newPlot(                        "a6d34e3a-19c2-4060-b8e8-877c1e214dc9",                        [{"x":["parametric","publications","clustering","extension","performance","inference","algorithm","documents","demonstrates","combination","considers","efficient","baselines","providing","proportions","eventually","posterior","experimentally","advantage","particles","distribution","dependent","collapsed","traditionally","expectation","initializes","degeneracy","sequential","demonstrate","technically","specifically","application","stochastic","algorithms","practical","investigate","challenging","experiments","detection","processing","consideration","detecting","information","paramount","concerned","considering","preventing","feasibility","approaches","systematically","popularity","constrained","increasingly","filtering","optimization","completion","processes","syllables","parameter","comprising","collection","structure","capturing","component","description","particular","indicating","described","procedure","configuration","retrieval","preliminary","situation","resulting","instances","instantiations","grounding","comparing","similarity","situations","architecture","relationships","indispensable","distinguishing","complementary","addressing","achieving","beneficial","representations","locations","convolutional","descriptions","discriminative","limitations","attribute","generally","recognizing","experimental","characteristics","belonging","classification","categories","promising","annotations","combining","tradeoffs","suggesting","exploration","different","centralized","maximizes","decentralized","relevance","generates","coordination","objective","additional","communication","fundamentally","exploitation","constraints","programming","informally","propositional","semantics","implementation","transitive","straightforward","monotonic","confidence","especially","indicators","translators","translation","improvement","applications","linguistic","inferring","traditional","evaluation","expensive","contrasting","judgments","introduces","probabilistic","selective","inconsistency","invaluable","credibility","estimation","intelligent","correlation","subsequently","engineered","ingenious","distributions","corrected","modifying","importance","introduce","carefully","rejection","correction","motivated","reference","recognition","rotational","resolution","calculating","rigorously","respectively","statistics","definition","projecting","projected","projection","descriptor","available","neighboring","occlusion","technique","descriptors","techniques","exhibited","hierarchical","classifiers","extensive","selection","automated","asymptotic","discrimination","important","effectiveness","hypothesis","properties","classifier","divergence","categorization","framework","foundation","substitution","biological","similarities","methodology","molecules","functions","precisely","databases","mathematical","benchmark","classifications","affinities","respective","segmentations","computations","calculated","probability","approximation","resorting","meaningful","quantitative","probabilities","recurrent","segmentation","languages","developed","sequences","segmented","uncertainty","contribution","knowledge","reasoning","representation","extensions","monitoring","dynamically","quantification","associated","inherently","composition","uncertain","automatically","generated","enterprises","predicates","occurrence","increased","environment","constructing","optimized","classifies","untrimmed","dimensional","continuous","can ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	ingenious
# 	resorting
# 	corruptions
# 	determinantal
# 	convexification
# 	stagewise
# 	admitting
# 	vectorial
# 	misspecified
# 	semiparametric
# 	radiographs
# 	regulations
# 	minibatch
# 	bhattacharya
# 	misclassify
# 	fluctuation
# 	econometrics
# 	emissions
# 	distinguishability
# 	affirmative
# Some words which never appear in Statistics papers:
# 	syllables
# 	grounding
# 	propositional
# 	translators
# 	credibility
# 	rotational
# 	enterprises
# 	predicates
# 	untrimmed
# 	activitynet
# 	localizing
# 	prohibiting
# 	stigmergy
# 	comprised
# 	deliberately
# 	assistive
# 	manipulators
# 	necessitated
# 	superpixel
# 	grammatical

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.080145382862071e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7458333333333333
